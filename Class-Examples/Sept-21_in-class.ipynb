# %%
import json
import pandas as pd

# %%
with open(r"C:\Users\dsilva2\EMAT22110_FA21\facebook-davidsilva100046_year\messages\inbox\chessbuds_npjakt9u1g\message_1.json") as d:
    dat = json.load(d)

# %%
dat

# %%
dat.keys()
# Out:
# dict_keys(['participants', 'messages', 'title', 'is_still_participant', 'thread_type', 'thread_path', 'magic_words'])

# %%
df_messages = pd.DataFrame(dat['messages'])

# %%
df_messages.head(2)
# Out:
#    sender_name   timestamp_ms             content     type  is_unsent  \
# 0  Scott Pence  1630008598158  New high score!!!!  Generic      False
# 1  Scott Pence  1630008589661                 NaN  Generic      False
#
#                                               photos share reactions gifs  \
# 0                                                NaN   NaN       NaN  NaN
# 1  [{'uri': 'messages/inbox/chessbuds_npjakt9u1g/...   NaN       NaN  NaN
#
#   users
# 0   NaN
# 1   NaN

# %%
df_messages.tail(8)
# Out:
#       sender_name   timestamp_ms  \
# 113   Aaron Rusch  1616196125586
# 114  Joanna Rusch  1615867627411
# 115   Scott Pence  1615855703137
# 116   Scott Pence  1615855643693
# 117   Scott Pence  1615855620614
# 118   Chad Larson  1615854725212
# 119   Chad Larson  1615854680797
# 120   Chad Larson  1615854650355
#
#                                                content       type  is_unsent  \
# 113                                                NaN    Generic      False
# 114                                       Nice, Scott!    Generic      False
# 115  Just wait until I have the black piece. I stil...    Generic      False
# 116                              Thank you, thank you.    Generic      False
# 117                                                NaN    Generic      False
# 118  Chad Larson added Angela Babbitt Pence to the ...  Subscribe      False
# 119  Scott studied my games, did a specific opening...    Generic      False
# ...

# %%
df_messages.loc[5:9]
# Out:
#     sender_name   timestamp_ms  \
# 5   Chad Larson  1628981388010
# 6   Scott Pence  1628963882425
# 7   Scott Pence  1628963877254
# 8  Joanna Rusch  1626214598778
# 9   Scott Pence  1622740925239
#
#                                              content     type  is_unsent  \
# 5  That's awesome!  I haven't done it before...di...  Generic      False
# 6                                                NaN  Generic      False
# 7  I was able to tie my puzzle record today. I th...  Generic      False
# 8  https://www.nytimes.com/2021/07/13/sports/ches...    Share      False
# 9              Yeah that's weird. But also twinsies!  Generic      False
#
#                                               photos  \
# 5                                                NaN
# 6  [{'uri': 'messages/inbox/chessbuds_npjakt9u1g/...
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
# ...

# %%
df_messages.iloc[-5:-1]
# Out:
#      sender_name   timestamp_ms  \
# 116  Scott Pence  1615855643693
# 117  Scott Pence  1615855620614
# 118  Chad Larson  1615854725212
# 119  Chad Larson  1615854680797
#
#                                                content       type  is_unsent  \
# 116                              Thank you, thank you.    Generic      False
# 117                                                NaN    Generic      False
# 118  Chad Larson added Angela Babbitt Pence to the ...  Subscribe      False
# 119  Scott studied my games, did a specific opening...    Generic      False
#
#     photos share                                       reactions  \
# 116    NaN   NaN                                             NaN
# 117    NaN   NaN  [{'reaction': 'ð', 'actor': 'Chad Larson'}]
# 118    NaN   NaN                                             NaN
# 119    NaN   NaN                                             NaN
#
#                                                   gifs  \
# ...

# %%
df_messages.iloc[-5:]
# Out:
#      sender_name   timestamp_ms  \
# 116  Scott Pence  1615855643693
# 117  Scott Pence  1615855620614
# 118  Chad Larson  1615854725212
# 119  Chad Larson  1615854680797
# 120  Chad Larson  1615854650355
#
#                                                content       type  is_unsent  \
# 116                              Thank you, thank you.    Generic      False
# 117                                                NaN    Generic      False
# 118  Chad Larson added Angela Babbitt Pence to the ...  Subscribe      False
# 119  Scott studied my games, did a specific opening...    Generic      False
# 120                   Chad named the group Chess Buds.    Generic      False
#
#     photos share                                       reactions  \
# 116    NaN   NaN                                             NaN
# 117    NaN   NaN  [{'reaction': 'ð', 'actor': 'Chad Larson'}]
# 118    NaN   NaN                                             NaN
# ...

# %%
df_messages[df_messages['timestamp_ms'] >= 1615854680797]
# Out:
#      sender_name   timestamp_ms  \
# 0    Scott Pence  1630008598158
# 1    Scott Pence  1630008589661
# 2    Chad Larson  1628981529595
# 3    Scott Pence  1628981489380
# 4    Scott Pence  1628981472084
# ..           ...            ...
# 115  Scott Pence  1615855703137
# 116  Scott Pence  1615855643693
# 117  Scott Pence  1615855620614
# 118  Chad Larson  1615854725212
# 119  Chad Larson  1615854680797
#
#                                                content       type  is_unsent  \
# 0                                   New high score!!!!    Generic      False
# 1                                                  NaN    Generic      False
# 2    Ooo I will have to try it.  I gotta download a...    Generic      False
# 3                                   You get 3 strikes.    Generic      False
# 4         17 total. My longest streak was 10 in a row.    Generic      False
# ..                                                 ...        ...        ...
# ...

# %%
df_subset = df_messages[((df_messages['sender_name'] == "Scott Pence") | (df_messages['sender_name'] == "Chad Larson")) & (df_messages['timestamp_ms'] < 1628981489380)]

# %%
df_subset.loc[5:13]
# Out:
#     sender_name   timestamp_ms  \
# 5   Chad Larson  1628981388010
# 6   Scott Pence  1628963882425
# 7   Scott Pence  1628963877254
# 9   Scott Pence  1622740925239
# 10  Chad Larson  1622737036016
# 11  Scott Pence  1622736962167
# 12  Scott Pence  1622736949089
# 13  Chad Larson  1622736822944
#
#                                               content     type  is_unsent  \
# 5   That's awesome!  I haven't done it before...di...  Generic      False
# 6                                                 NaN  Generic      False
# 7   I was able to tie my puzzle record today. I th...  Generic      False
# 9               Yeah that's weird. But also twinsies!  Generic      False
# 10  Looks like my game didn't include your latest ...  Generic      False
# 11                                                NaN  Generic      False
# 12  Weird, I have different accuracy numbers on my...  Generic      False
# 13                 Identical for that game Scott haha  Generic      False
#
# ...

# %%
df_subset.iloc[5:13]
# Out:
#     sender_name   timestamp_ms  \
# 10  Chad Larson  1622737036016
# 11  Scott Pence  1622736962167
# 12  Scott Pence  1622736949089
# 13  Chad Larson  1622736822944
# 14  Chad Larson  1622736816739
# 16  Scott Pence  1622675685437
# 17  Chad Larson  1622675491165
# 18  Chad Larson  1622675474899
#
#                                               content     type  is_unsent  \
# 10  Looks like my game didn't include your latest ...  Generic      False
# 11                                                NaN  Generic      False
# 12  Weird, I have different accuracy numbers on my...  Generic      False
# 13                 Identical for that game Scott haha  Generic      False
# 14                                                NaN  Generic      False
# 16                                                NaN  Generic      False
# 17             It was a great one.  Aaron is so proud  Generic      False
# 18  I needed a new phone anyways.  I think it will...  Generic      False
#
# ...

# %%
type(df_messages.loc[0].photos)
# Out:
# float

# %%
df_messages[df_messages['photos'].notna()]
# Out:
#     sender_name   timestamp_ms content     type  is_unsent  \
# 1   Scott Pence  1630008589661     NaN  Generic      False
# 6   Scott Pence  1628963882425     NaN  Generic      False
# 11  Scott Pence  1622736962167     NaN  Generic      False
# 14  Chad Larson  1622736816739     NaN  Generic      False
# 62  Scott Pence  1617385304150     NaN  Generic      False
#
#                                                photos share reactions gifs  \
# 1   [{'uri': 'messages/inbox/chessbuds_npjakt9u1g/...   NaN       NaN  NaN
# 6   [{'uri': 'messages/inbox/chessbuds_npjakt9u1g/...   NaN       NaN  NaN
# 11  [{'uri': 'messages/inbox/chessbuds_npjakt9u1g/...   NaN       NaN  NaN
# 14  [{'uri': 'messages/inbox/chessbuds_npjakt9u1g/...   NaN       NaN  NaN
# 62  [{'uri': 'messages/inbox/chessbuds_npjakt9u1g/...   NaN       NaN  NaN
#
#    users
# 1    NaN
# 6    NaN
# 11   NaN
# 14   NaN
# 62   NaN

# %%
df_messages[['sender_name', 'photos', 'gifs']]
# Out:
#      sender_name                                             photos  \
# 0    Scott Pence                                                NaN
# 1    Scott Pence  [{'uri': 'messages/inbox/chessbuds_npjakt9u1g/...
# 2    Chad Larson                                                NaN
# 3    Scott Pence                                                NaN
# 4    Scott Pence                                                NaN
# ..           ...                                                ...
# 116  Scott Pence                                                NaN
# 117  Scott Pence                                                NaN
# 118  Chad Larson                                                NaN
# 119  Chad Larson                                                NaN
# 120  Chad Larson                                                NaN
#
#                                                   gifs
# 0                                                  NaN
# ...

# %%
df_messages.iloc[117].gifs
# Out:
# [{'uri': 'messages/inbox/chessbuds_npjakt9u1g/gifs/50203035_295326594670631_5010610380540477440_n_729120860993392.gif'}]
