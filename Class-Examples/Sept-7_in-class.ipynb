# %%
import pandas as pd
import json

# %%
with open(r"C:\Users\dsilva2\EMAT22110_FA21\technogecko_20210830\information_about_you\ads_interests.json") as j:
    dat1 = json.load(j)
    
with open(r"C:\Users\dsilva2\EMAT22110_FA21\technogecko_20210830\followers_and_following\followers.json") as k:
    dat2 = json.load(k)

# %%
dat1.keys()
# Out:
# dict_keys(['inferred_data_ig_interest'])

# %%
dat1['inferred_data_ig_interest']
# Out:
# [{'title': '',
#   'media_map_data': {},
#   'string_map_data': {'Interest': {'href': '',
#     'value': 'Shopping and fashion',
#     'timestamp': 0}}},
#  {'title': '',
#   'media_map_data': {},
#   'string_map_data': {'Interest': {'href': '',
#     'value': 'Hispanic culture',
#     'timestamp': 0}}},
#  {'title': '',
#   'media_map_data': {},
#   'string_map_data': {'Interest': {'href': '',
#     'value': 'Betty Crocker',
#     'timestamp': 0}}},
#  {'title': '',
#   'media_map_data': {},
#   'string_map_data': {'Interest': {'href': '',
#     'value': 'Social justice',
#     'timestamp': 0}}},
#  {'title': '',
#   'media_map_data': {},
#   'string_map_data': {'Interest': {'href': '',
#     'value': 'Sister Act',
#     'timestamp': 0}}},
#  {'title': '',
#   'media_map_data': {},
#   'string_map_data': {'Interest': {'href': '',
#     'value': 'Black Sabbath',
#     'timestamp': 0}}},
#  {'title': '',
#   'media_map_data': {},
#   'string_map_data': {'Interest': {'href': '',
# ...

# %%
dat1
# Out:
# {'inferred_data_ig_interest': [{'title': '',
#    'media_map_data': {},
#    'string_map_data': {'Interest': {'href': '',
#      'value': 'Shopping and fashion',
#      'timestamp': 0}}},
#   {'title': '',
#    'media_map_data': {},
#    'string_map_data': {'Interest': {'href': '',
#      'value': 'Hispanic culture',
#      'timestamp': 0}}},
#   {'title': '',
#    'media_map_data': {},
#    'string_map_data': {'Interest': {'href': '',
#      'value': 'Betty Crocker',
#      'timestamp': 0}}},
#   {'title': '',
#    'media_map_data': {},
#    'string_map_data': {'Interest': {'href': '',
#      'value': 'Social justice',
#      'timestamp': 0}}},
#   {'title': '',
#    'media_map_data': {},
#    'string_map_data': {'Interest': {'href': '',
#      'value': 'Sister Act',
#      'timestamp': 0}}},
#   {'title': '',
#    'media_map_data': {},
#    'string_map_data': {'Interest': {'href': '',
#      'value': 'Black Sabbath',
#      'timestamp': 0}}},
#   {'title': '',
# ...

# %%
type(dat1['inferred_data_ig_interest'])
# Out:
# list

# %%
type(dat1)
# Out:
# dict

# %%
len(dat1['inferred_data_ig_interest'])
# Out:
# 227

# %%
interests = [x['string_map_data']['Interest']['value'] for x in dat1['inferred_data_ig_interest']]

# %%
interests
# Out:
# ['Shopping and fashion',
#  'Hispanic culture',
#  'Betty Crocker',
#  'Social justice',
#  'Sister Act',
#  'Black Sabbath',
#  'Latino culture',
#  'Gender identity',
#  'Belk',
#  'Donation',
#  'Retail',
#  'International Headache Society',
#  'Magnum (ice cream)',
#  "Macy's",
#  'Glastonbury Festival',
#  'Human sexuality',
#  'American folk music',
#  'Delhi Metro',
#  'Spritz (alcoholic beverage)',
#  'Lunch box',
#  'The Cheesecake Factory',
#  'Jan Oblak',
#  'Soap opera',
#  'Packed lunch',
#  'Tiger of Sweden',
#  'Association football (Soccer)',
#  'Neubau',
#  'Culture',
#  'MIT Sloan School of Management',
#  'Greek mythology',
#  'Wireless Festival',
#  'Comedy movies',
#  'Expressen',
#  'Cultural diversity',
#  'Firefighter.com',
#  'Model United Nations',
#  'Fundraising',
#  'African-American dance',
#  'Social movement',
#  'University of the Philippines Mindanao',
#  'Persol',
#  'Target Baby',
#  'Medi 1 TV',
#  'Istituto Italiano di Cultura',
#  'Monochrome',
# ...
